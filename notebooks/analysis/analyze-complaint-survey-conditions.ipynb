# %% [markdown]
# # Analyze Complaint Survey Conditions
#
# This notebook analyzes whether BrightSpring has received more conditions in complaint surveys (referred to as **Complaint** surveys in QCOR) than other providers in the seven states with the most for-profit facilities. The analysis looks only at **smaller** (4-8 bed) facilities.

# %%
import pandas as pd
import glob
import datetime

# %%
ownership_data = (
    pd
    .concat(
        [
            pd
            .read_csv(
                f, 
                parse_dates=["termination_date", "particip_date"]
            ) for f in glob.glob("../../data/ownership/final/*.csv")
        ]
    )
)

# %%
ownership_data.head()
# Out:
#   provider_id                        name  \
# 0      51G002       5TH AVENUE GROUP HOME
# 1      51G003              POTOMAC CENTER
# 2      51G007      CROSS LANES GROUP HOME
# 3      51G008    EIGHTH AVENUE GROUP HOME
# 4      51G009  VIRGINIA AVENUE GROUP HOME
#
#                                                 type              region  \
# 0  Intermediate Care Facilities for Individuals w...  (III) Philadelphia
# 1  Intermediate Care Facilities for Individuals w...  (III) Philadelphia
# 2  Intermediate Care Facilities for Individuals w...  (III) Philadelphia
# 3  Intermediate Care Facilities for Individuals w...  (III) Philadelphia
# 4  Intermediate Care Facilities for Individuals w...  (III) Philadelphia
#
#   state                                        address         phone  \
# 0    WV       916 FIFTH AVENUE\nSAINT ALBANS, WV 25177  304 720-0015
# 1    WV              ONE BLUE STREET\nROMNEY, WV 26757  304 822-3861
# 2    WV  5202 LINDA VISTA DRIVE\nCROSS LANES, WV 25313  304 776-2005
# 3    WV          1519 8TH AVENUE\nHUNTINGTON, WV 25701  304 523-0177
# 4    WV      821 VIRGINIA AVENUE\nHUNTINGTON, WV 25701  304 523-0196
#
#                                        address.1 particip_date  \
# 0       916 FIFTH AVENUE\nSAINT ALBANS, WV 25177    1981-10-06
# 1              ONE BLUE STREET\nROMNEY, WV 26757    1983-11-09
# 2  5202 LINDA VISTA DRIVE\nCROSS LANES, WV 25313    1986-11-17
# 3          1519 8TH AVENUE\nHUNTINGTON, WV 25701    1987-03-06
# 4      821 VIRGINIA AVENUE\nHUNTINGTON, WV 25701    1987-03-06
#
#    certified_beds hospital_based ownership_type termination_code  \
# 0               9             No     For Profit              NaN
# 1              24             No     Non-Profit              NaN
# 2               8             No     For Profit              NaN
# 3               8             No     For Profit              NaN
# 4               8             No     For Profit              NaN
#
#   termination_date                                      legal_owner  \
# 0              NaT                 RSCR WEST VIRGINIA, INCORPORATED
# 1              NaT                                   POTOMAC CENTER
# 2              NaT                 RSCR WEST VIRGINIA, INCORPORATED
# 3              NaT  VOCA CORPORATION OF WEST VIRGINIA, INCORPORATED
# 4              NaT  VOCA CORPORATION OF WEST VIRGINIA, INCORPORATED
#
#    is_brightspring
# 0             True
# 1            False
# 2             True
# 3             True
# 4             True

# %%
# Filter facilities by bed size
sm_state_owners = ownership_data.loc[
    lambda x: (x["certified_beds"] >= 4) &
    (x["certified_beds"] <= 8)
].copy()

# %%
len(sm_state_owners)
# Out:
# 3646

# %%
surveys = pd.read_csv("../../data/qcor/surveys.csv", parse_dates=["date"])
deficiencies = pd.read_csv("../../data/qcor/deficiencies.csv", parse_dates=["date"])

# %%
surveys.head()
# Out:
#       survey_key provider_id       date      type      subtype  \
# 0  01G005-2010-0      01G005 2010-11-24  STANDARD  LIFE SAFETY
# 1  01G005-2010-1      01G005 2010-11-24  STANDARD       HEALTH
# 2  01G005-2011-0      01G005 2011-07-27  STANDARD  LIFE SAFETY
# 3  01G005-2011-1      01G005 2011-07-27  STANDARD       HEALTH
# 4  01G006-2010-0      01G006 2010-07-27  STANDARD  LIFE SAFETY
#
#    num_deficiencies
# 0                43
# 1                 5
# 2                76
# 3                18
# 4                 0

# %%
survey_df = surveys.loc[
    lambda x: 
        x["provider_id"].isin(sm_state_owners["provider_id"]) & 
        (x["date"] >= "2019-03-05") & # Date KKR bought BrightSpring
        (x["date"] <= "2021-12-31") & # Last date for data
        (x["type"] == "COMPLAINT") & # Only Complaint surveys
        (x["subtype"] == "HEALTH") # Only Health surveys
].copy()

# %%
len(survey_df)
# Out:
# 7464

# %%
deficiencies.sample(5)
# Out:
#            survey_key     level    tag  \
# 318169  39G041-2018-0  Standard  K0258
# 312561  37G133-2018-1  Standard  W0323
# 317614  39G036-2013-0  Standard  K0341
# 294533  36G402-2012-1  Standard  W0209
# 282327  36G026-2011-1  Standard  K0352
#
#                                                  desc       date
# 318169  Number of Exits - Patient Sleeping and Non-Sl 2018-08-28
# 312561                             PHYSICIAN SERVICES 2018-10-17
# 317614               Fire Alarm System - Installation 2013-02-06
# 294533                        INDIVIDUAL PROGRAM PLAN 2012-05-31
# 282327         Sprinkler System - Supervisory Signals 2011-05-02

# %%
con_df = deficiencies.loc[
    lambda x: 
        (x["level"] == "Condition") &
        x["survey_key"].isin(survey_df["survey_key"])
]

# %%
len(con_df)
# Out:
# 558

# %%
con_surveys = (
    con_df
    .groupby("survey_key")["tag"]
    .count()
    .to_frame()
    .rename(columns={"tag": "condition_count"})
    .reset_index()
)

# %%
con_surveys.head()
# Out:
#       survey_key  condition_count
# 0  05G080-2019-0                1
# 1  05G104-2020-2                1
# 2  05G148-2020-0                2
# 3  05G149-2019-1                2
# 4  05G149-2021-2                2

# %%
last_survey_date = survey_df["date"].max()

# %%
last_survey_date
# Out:
# Timestamp('2021-12-31 00:00:00')

# %%
acquisition_date = pd.Timestamp(year=2019, month=3, day=5)
end_date = pd.Timestamp(year=2021, month=12, day=31)

# %%
def calc_overall_days_open(row):
    if pd.isnull(row["termination_date"]): # facility still open
        if row["particip_date"] <= acquisition_date: # open the whole time
            delta = end_date - acquisition_date
            return delta.days
        else: # opened during time, still open
            delta = last_survey_date - row["particip_date"]
            return delta.days
    else:
        if row["particip_date"] <= acquisition_date: # opened before time, now closed
            delta = row["termination_date"] - acquisition_date
            return delta.days
        else: # opened after start, now closed
            delta = row["termination_date"] - row["particip_date"]
            return delta.days

# %%
sm_state_owners.dtypes
# Out:
# provider_id                 object
# name                        object
# type                        object
# region                      object
# state                       object
# address                     object
# phone                       object
# address.1                   object
# particip_date       datetime64[ns]
# certified_beds               int64
# hospital_based              object
# ownership_type              object
# termination_code            object
# termination_date    datetime64[ns]
# legal_owner                 object
# is_brightspring               bool
# dtype: object

# %%
sm_state_owners["days_open"] = (
    sm_state_owners
    .apply(
        lambda x: calc_overall_days_open(x), axis=1
    )
)

sm_state_owners["bed_days_open"] = (
    sm_state_owners
    .apply(
        lambda x: x["days_open"] * x["certified_beds"], axis=1
    )
)

# %%
sm_state_owners.head()
# Out:
#   provider_id                        name  \
# 2      51G007      CROSS LANES GROUP HOME
# 3      51G008    EIGHTH AVENUE GROUP HOME
# 4      51G009  VIRGINIA AVENUE GROUP HOME
# 5      51G010   811 S. KANAWHA GROUP HOME
# 6      51G011  1204 S. KANAWHA GROUP HOME
#
#                                                 type              region  \
# 2  Intermediate Care Facilities for Individuals w...  (III) Philadelphia
# 3  Intermediate Care Facilities for Individuals w...  (III) Philadelphia
# 4  Intermediate Care Facilities for Individuals w...  (III) Philadelphia
# 5  Intermediate Care Facilities for Individuals w...  (III) Philadelphia
# 6  Intermediate Care Facilities for Individuals w...  (III) Philadelphia
#
#   state                                        address         phone  \
# 2    WV  5202 LINDA VISTA DRIVE\nCROSS LANES, WV 25313  304 776-2005
# 3    WV          1519 8TH AVENUE\nHUNTINGTON, WV 25701  304 523-0177
# 4    WV      821 VIRGINIA AVENUE\nHUNTINGTON, WV 25701  304 523-0196
# 5    WV       811 S. KANAWHA STREET\nBECKLEY, WV 25801  304 252-5937
# 6    WV      1204 S. KANAWHA STREET\nBECKLEY, WV 25801  304 252-5676
#
#                                        address.1 particip_date  \
# 2  5202 LINDA VISTA DRIVE\nCROSS LANES, WV 25313    1986-11-17
# 3          1519 8TH AVENUE\nHUNTINGTON, WV 25701    1987-03-06
# 4      821 VIRGINIA AVENUE\nHUNTINGTON, WV 25701    1987-03-06
# 5       811 S. KANAWHA STREET\nBECKLEY, WV 25801    1987-02-17
# 6      1204 S. KANAWHA STREET\nBECKLEY, WV 25801    1987-02-17
#
#    certified_beds hospital_based ownership_type termination_code  \
# 2               8             No     For Profit              NaN
# 3               8             No     For Profit              NaN
# 4               8             No     For Profit              NaN
# 5               8             No     For Profit              NaN
# 6               8             No     For Profit              NaN
#
#   termination_date                                      legal_owner  \
# 2              NaT                 RSCR WEST VIRGINIA, INCORPORATED
# 3              NaT  VOCA CORPORATION OF WEST VIRGINIA, INCORPORATED
# 4              NaT  VOCA CORPORATION OF WEST VIRGINIA, INCORPORATED
# 5              NaT  VOCA CORPORATION OF WEST VIRGINIA, INCORPORATED
# 6              NaT  VOCA CORPORATION OF WEST VIRGINIA, INCORPORATED
#
#    is_brightspring  days_open  bed_days_open
# 2             True       1032           8256
# 3             True       1032           8256
# 4             True       1032           8256
# 5             True       1032           8256
# 6             True       1032           8256

# %% [markdown]
# ## Analysis Versus Everyone

# %%
overall_results = (
    survey_df
    .merge(
        con_surveys,
        how="left",
        on="survey_key"
    )
    .assign(condition_count = lambda df: df["condition_count"].fillna(0))
    .merge(
        sm_state_owners[[
            "provider_id", 
            "name", 
            "state", 
            "is_brightspring", 
            "bed_days_open"
        ]]
    )
    .groupby(["state", "is_brightspring"])
    .pipe(lambda grp: pd.DataFrame({
        "facs": grp["provider_id"].nunique(),
        "surveys": grp["survey_key"].nunique(),
        "conditions": grp["condition_count"].sum(),
        "total_bed_days_open": grp["bed_days_open"].sum()
    }))
    .assign(
        conditions_per_10000_bed_days = 
        lambda df: df["conditions"] / df["total_bed_days_open"] * 10000)
)

# %%
overall_results
# Out:
#                        facs  surveys  conditions  total_bed_days_open  \
# state is_brightspring
# CA    False             868     3827        95.0             23358694
#       True               87      650        28.0              3944340
# IN    False             227      438       129.0              3158868
#       True               76      203        64.0              1567908
# LA    False             100      128        40.0               915192
#       True               36       58        20.0               423612
# NC    False             130      264        12.0              1623336
#       True               30       74         4.0               456144
# OH    False              33       46         8.0               352208
#       True               22       34        14.0               262040
# TX    False             509     1212        23.0              7453519
#       True              178      498        74.0              3058848
# WV    False               4        4         4.0                27864
#       True               17       28        43.0               206736
#
#                        conditions_per_10000_bed_days
# state is_brightspring
# CA    False                                 0.040670
#       True                                  0.070988
# IN    False                                 0.408374
#       True                                  0.408187
# LA    False                                 0.437067
#       True                                  0.472130
# NC    False                                 0.073922
#       True                                  0.087692
# OH    False                                 0.227139
#       True                                  0.534270
# TX    False                                 0.030858
#       True                                  0.241921
# WV    False                                 1.435544
#       True                                  2.079947

# %% [markdown]
# The final results below are BrightSpring's total conditions per 10,000 bed days for 4-8 bed facilities (**True** column) versus everyone else (**False** column), the ratio of the two values, and the difference of the two values for each state.

# %%
(
    overall_results["conditions_per_10000_bed_days"]
    .unstack()
    .assign(vs_rest_ratio = lambda df: df[True] / df[False])
    .assign(vs_rest_difference = lambda df: df[True] - df[False])
    .round(2)
    .sort_values("vs_rest_ratio", ascending=False)
)
# Out:
# is_brightspring  False  True  vs_rest_ratio  vs_rest_difference
# state
# TX                0.03  0.24           7.84                0.21
# OH                0.23  0.53           2.35                0.31
# CA                0.04  0.07           1.75                0.03
# WV                1.44  2.08           1.45                0.64
# NC                0.07  0.09           1.19                0.01
# LA                0.44  0.47           1.08                0.04
# IN                0.41  0.41           1.00               -0.00

# %% [markdown]
# ----
#
# ----
#
# ----
