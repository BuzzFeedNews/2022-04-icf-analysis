# %% [markdown]
# # Clean up California Ownership Data
#
# This notebook takes the data scraped from BuzzFeed News from the Cal Health Find Database, plus additional data from the state of California and combines it with the data from QCOR to output the data for the final analysis.

# %%
import pandas as pd

# %% [markdown]
# ## Load CDPH Data Re-Formatted for QCOR
#
# The data below was initially scraped from the [Cal Health Find Database](https://www.cdph.ca.gov/Programs/CHCQ/LCP/CalHealthFind/Pages/SearchResult.aspx).

# %%
RAW_OWNERSHIP_DIR = "../../data/ownership/raw/"
INTERMEDIATE_OWNERSHIP_DIR = "../../data/ownership/intermediate/"

# %%
ca_state = pd.read_csv(
    INTERMEDIATE_OWNERSHIP_DIR + 
    "california-data-for-qcor.csv"
).dropna(subset=["HFCISFacilityProviderNumber"])

# %%
len(ca_state)
# Out:
# 1058

# %%
ca_state.head()
# Out:
#                                          clean_owner  HFCISFacilityAddress  \
# 0  United Cerebral Palsy/Spastic Children's Found...   13272 Dronfield Ave
# 1                                         Portsmouth  27695 Portsmouth Ave
# 2                               St. Mary Investments         3706 Pine Ave
# 3                                    LRC Homes, Inc.      24402 Aphena Ave
# 4                        MITCHELL HOMES INCORPORATED      1280 Mcandrew Rd
#
#   HFCISFacilityCity HFCISFacilityCounty  HFCISFacilityID    HFCISFacilityName  \
# 0            Sylmar         LOS ANGELES        960001997  UCP DRONFIELD NORTH
# 1           Hayward             ALAMEDA         20001191   PORTSMOUTH ICF/DDH
# 2        Long Beach         LOS ANGELES        960001702    BIXBY KNOLL PLACE
# 3     Mission Viejo              ORANGE        630004641          LORI'S HOME
# 4              Ojai             VENTURA         50000629        MITCHELL HOME
#
#    HFCISFacilityZIPCode  HFCISNPINumber HFCISFacilityProviderNumber  \
# 0                 91342    1.831342e+09                      05G973
# 1                 94545    1.861534e+09                      55G320
# 2                 90807    1.427266e+09                      05G725
# 3                 92691    1.588731e+09                      55G559
# 4                 93023    1.750406e+09                      05G578
#
#   HFCISInitialLicenseDate
# 0              1996-02-13
# 1              1999-10-27
# 2              1993-10-28
# 3              2006-04-11
# 4              1992-04-20

# %% [markdown]
# ## Load Spreadsheets California Provided
#
# In addition to the Cal Health Find Database, BuzzFeed News requested the ownership information for facilities that were either closed or recently opened, because they did not appear on the website. That information was provided by the state in two additional Excel files.

# %%
other_ca_state = pd.read_excel(RAW_OWNERSHIP_DIR + "california-missing-facility-list-ICF-DDS.xlsx")

# %%
other_ca_state.head()
# Out:
#    #                                      name particip_date provider_id  \
# 0  1                           CASA DEL MAR #1    1985-08-14      05G178
# 1  2                       HASSIBAH - TLC, INC    1987-02-10      05G246
# 2  3  ADULTS IN COMMUNITY TRANSITION - A C T 1    1988-09-08      05G314
# 3  4                             CASA TERCEIRA    1988-09-20      05G342
# 4  5      LOYD'S LIBERTY HOMES, INC - SAN JOSE    1989-11-16      05G400
#
#   Facility Status CalHealthFind Status                     Licensee name  \
# 0            Open        Exists in CHF          J & J Care Centers, Inc.
# 1          Closed                  NaN              Hassibah - Tlc, Inc.
# 2          Closed                  NaN  Advocates For Independent Living
# 3          Closed                  NaN   Noia Residential Services, Inc.
# 4          Closed                  NaN        Loyd's Liberty Homes, Inc.
#
#   Facility Type Closed Date
# 0        ICFDDN         NaT
# 1        ICFDDN  2020-05-01
# 2        ICFDDH  2019-05-31
# 3        ICFDDH  2020-04-22
# 4        ICFDDN  2021-04-16

# %%
historical_ca_state = pd.read_excel(RAW_OWNERSHIP_DIR + "ICF-DD_Facility_Closures_and_Ownership_FINAL.xlsx")

# %%
historical_ca_state.head()
# Out:
#                  NAME PROVIDER_ID STATE  \
# 0    ALPINE HOME, THE      05G579    CA
# 1     ALTA LOMA HOUSE      05G697    CA
# 2             ANACAPA      55G758    CA
# 3        ANTON'S HOME      55G447    CA
# 4  ARLINGTON HOME # 1      05G582    CA
#
#                                              ADDRESS      FACID  \
# 0                6156 RIPLEY LANE PARADISE, CA 95969  230000427
# 1   10366 ALTA LOMA DRIVE RANCHO CUCAMONGA, CA 91701  240001246
# 2  2538 ANACAPA DRIVE, APT. 101/108, COSTA MESA, ...  630015860
# 3             2598 OLYMPIC DRIVE SAN BRUNO, CA 94066  220001147
# 4              1750 ARLINGTON AVE TORRANCE, CA 90501  960001484
#
#   FAC_STATUS_TYPE_CODE     FAC_CLOSURE_DATE DESCRIPTION  \
# 0               Closed  2018-11-16 00:00:00    Licensee
# 1               Closed  2018-05-18 00:00:00    Licensee
# 2                 Open                  NaN    Licensee
# 3               Closed  2021-04-08 00:00:00    Licensee
# 4               Closed  2017-09-14 00:00:00    Licensee
#
#               BUSINESS_NAME                FIRST_NAME MIDDLE_INITIAL  \
# 0             None on File                      Marna            NaN
# 1           Rockcreek, Inc.             Rockcreek INC            NaN
# 2     RSCR California, Inc.      RSCR California INC             NaN
# 3        ANTON'S HOME, INC.                 Estelita             NaN
# 4  Arlington Home Care Inc.  Arlington Home Care Inc.            NaN
#
#       LAST_NAME
# 0         Carli
# 1           NaN
# 2           NaN
# 3  Evangelista
# 4           NaN

# %% [markdown]
# ## Load QCOR Data

# %%
ca_facs = (
    pd
    .read_csv("../../data/qcor/facilities.csv", parse_dates=["termination_date"])
    .loc[
        lambda x: 
         (x["state"] == "CA") & 
         (
             x["termination_code"].isnull() | 
             (x["termination_date"] >= "2017-03-01")
         )
    ]
)

# %%
len(ca_facs)
# Out:
# 1166

# %%
ca_facs.head()
# Out:
#                                            name provider_id  \
# 63  PORTERVILLE DEVELOPMENT CENTER - DP ICF/IID      05G014
# 64                     GOLDEN STATE CARE CENTER      05G015
# 65                         HY-LOND GARDEN GROVE      05G017
# 66                              EDGEWOOD CENTER      05G019
# 67                        GLENRIDGE CENTER #140      05G020
#
#                                                  type              region  \
# 63  Intermediate Care Facilities for Individuals w...  (IX) San Francisco
# 64  Intermediate Care Facilities for Individuals w...  (IX) San Francisco
# 65  Intermediate Care Facilities for Individuals w...  (IX) San Francisco
# 66  Intermediate Care Facilities for Individuals w...  (IX) San Francisco
# 67  Intermediate Care Facilities for Individuals w...  (IX) San Francisco
#
#    state                                           address         phone  \
# 63    CA           26501 AVENUE 140\nPORTERVILLE, CA 93257  559 782-2222
# 64    CA  1758 N BIG DALTON AVENUE\nBALDWIN PARK, CA 91706  626 962-3274
# 65    CA          9861 11TH STREET\nGARDEN GROVE, CA 92844  714 531-8741
# 66    CA               200 WEST PARAMOUNT\nAZUSA, CA 91702  626 334-7861
# 67    CA      611 SOUTH CENTRAL AVENUE\nGLENDALE, CA 91204  818 637-7727
#
#    particip_date  certified_beds hospital_based ownership_type  \
# 63    1980-03-01             512             No     Government
# 64    1978-12-01             155             No     For Profit
# 65    1978-05-01              59             No     Government
# 66    1978-10-01              45             No     For Profit
# 67    1978-11-01              59             No     For Profit
#
#    termination_code termination_date
# 63              NaN              NaT
# 64              NaN              NaT
# 65        Vol-Other       2019-11-12
# 66              NaN              NaT
# 67              NaN              NaT

# %% [markdown]
# There is one facility that was opened after BuzzFeed News scraped the data from the Cal Health Find Database. Further research determined it is not owned by BrightSpring.

# %%
missing_facs = ca_facs.loc[lambda x: ~x["provider_id"].isin(ca_state["HFCISFacilityProviderNumber"])]

# %%
missing_facs.loc[
    lambda x: ~x["provider_id"].isin(historical_ca_state["PROVIDER_ID"]) & ~x["termination_code"].isnull()
]
# Out:
#                                      name provider_id  \
# 253  LOYD'S LIBERTY HOMES, INC - SAN JOSE      05G400
#
#                                                   type              region  \
# 253  Intermediate Care Facilities for Individuals w...  (IX) San Francisco
#
#     state                                 address         phone particip_date  \
# 253    CA  3567 SAN JOSE AVENUE\nMERCED, CA 95340  209 384-5833    1989-11-16
#
#      certified_beds hospital_based ownership_type termination_code  \
# 253               6             No     For Profit  Vol-Merg, Close
#
#     termination_date
# 253       2021-05-03

# %% [markdown]
# ## Merge the datasets and create the final set

# %%
def find_owner(row):
    if pd.notnull(row["clean_owner"]):
        return row["clean_owner"]
    else:
        if row["Licensee name"] in ["Res-Care California, Inc.", "RSCR California, Inc.", "RSCR INLAND, INC."]:
            return "BrightSpring"
        else:
            return row["Licensee name"]

# %%
combined_state_owner_info = (
    pd
    .concat([
        ca_state[
            ["HFCISFacilityProviderNumber", "clean_owner"]
        ]
        .rename(columns={"HFCISFacilityProviderNumber": "provider_id"}),
        other_ca_state[
            ["provider_id", "Licensee name", "Closed Date"]
        ],
        historical_ca_state[
            ["PROVIDER_ID", "BUSINESS_NAME", "FAC_CLOSURE_DATE"]
        ]
        .rename(columns={
            "PROVIDER_ID": "provider_id", 
            "BUSINESS_NAME": "Licensee name", 
            "FAC_CLOSURE_DATE": "Closed Date"
        })
    ])
    .assign(owner = lambda df: df.apply(lambda x: find_owner(x), axis=1))
    [["provider_id", "owner", "Closed Date"]]
    .drop_duplicates(subset="provider_id")
)

# %%
def clean_closed_date(row):
    if not pd.isnull(row["Closed Date"]):
        return row["Closed Date"]
    elif not pd.isnull(row["termination_date"]):
        return row["termination_date"]
    else:
        return None

# %%
# Final data for analysis
final_ca_ownership = (
    ca_facs
    .merge(
        combined_state_owner_info,
        how="left",
        left_on="provider_id",
        right_on="provider_id"
    )
    .assign(termination_date = lambda df: df.apply(clean_closed_date, axis=1))
    .assign(is_brightspring = lambda df: df["owner"] == "BrightSpring")
    .rename(columns={"owner": "legal_owner"})
)

# %%
len(final_ca_ownership)
# Out:
# 1166

# %%
# output for analysis
final_ca_ownership[[
    "name", "provider_id", "type", "region", "state", "address",
    "phone", "address", "particip_date", "certified_beds",
    "hospital_based", "ownership_type", "termination_code",
    "termination_date", "legal_owner", "is_brightspring"
]].to_csv("../../data/ownership/final/ca.csv", index=None)

# %% [markdown]
# ---
#
# ---
#
# ---
